# %% [markdown]
# ___
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://d33wubrfki0l68.cloudfront.net/4ec62c1c925a380c912ddad740d18554c6822a11/fabe4/img/sponsors/iteso-university.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Keysi Fuentes, Larissa Gracian
#
# **Fecha:** XX de octubre del 202X.
#
# **Expediente** : XXX.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**:
#
# # Simulación y Análisis del Impacto  Colisiones Severas y Fatales

# %% [markdown]
# ## Objetivos.
#
# ### 1.1 Objetivo general.
# - Desarrollar un modelo de simulación financiera para analizar el impacto  de colisiones severas y fatales en distintas regiones geográficas y poder predecir cuantas personas se moriran o tendra colisiones severas en el prox mes
#
# ### 1.2 Objetivos específicos
# 1. Recolectar y procesar datos históricos de colisiones severas y fatales, así como de variables demográficas y de tráfico.
# 2. Desarrollar algoritmos y modelos matemáticos para simular el comportamiento de las variables relacionadas con las colisiones, como la tasa de colisiones por 100,000 personas.
# 3. Implementar técnicas de validación cruzada y análisis de errores para validar el modelo de simulación desarrollado.
# 4. Realizar simulaciones computacionales para evaluar diferentes escenarios de colisiones severas y fatales en distintas regiones geográficas, considerando diferentes modos de transporte como vehículos, motocicletas, peatones y ciclistas.
# 5. Analizar los resultados obtenidos de las simulaciones para identificar patrones, tendencias y factores de riesgo asociados a las colisiones severas y fatales.
# 6. Proponer recomendaciones basadas en los resultados del análisis para mejorar la seguridad vial y reducir el impacto económico de las colisiones en las distintas regiones geográficas.
#
# ### 1. 3 Definición del problema
#
# El escenario de negocio que se va a modelar es el impacto económico de colisiones severas y fatales en distintas regiones geográficas. Se busca entender cómo estas colisiones afectan tanto a la población como a la infraestructura vial, con el fin de tomar medidas preventivas y de gestión de riesgos.
#
# **Supuestos:**
# 1. Las colisiones severas y fatales tienen un impacto económico significativo en términos de costos médicos, pérdida de productividad y daños a la propiedad.
# 2. Existe una relación entre la densidad de población, el volumen de tráfico y la tasa de colisiones en una determinada región geográfica.
# 3. Los datos históricos de colisiones y variables demográficas son representativos de la realidad actual y pueden utilizarse para predecir futuros escenarios.
#
# **Nodos o Escenarios a Simular:**
# 1. **Recolección de Datos:** Obtener datos históricos de colisiones severas y fatales, así como de variables demográficas y de tráfico.
# 2. **Procesamiento de Datos:** Limpiar, procesar y preparar los datos para su análisis.
# 3. **Desarrollo del Modelo:** Diseñar y desarrollar un modelo de simulación financiera que integre los datos de colisiones con variables demográficas y de tráfico.
# 4. **Validación del Modelo:** Utilizar técnicas de validación cruzada y análisis de errores para verificar la precisión y fiabilidad del modelo.
# 5. **Simulación Computacional:** Realizar simulaciones para evaluar el impacto económico de las colisiones severas y fatales en diferentes regiones geográficas y escenarios de tráfico.
# 6. **Análisis de Resultados:** Analizar los resultados de las simulaciones para identificar patrones, tendencias y factores de riesgo asociados a las colisiones.
# 7. **Propuestas y Recomendaciones:** Proponer recomendaciones basadas en los resultados del análisis para mejorar la seguridad vial y reducir el impacto económico de las colisiones en las distintas regiones geográficas.
#
# El siguiente diagrama representa los nodos o escenarios a simular en el proceso:
#
# ![image-2.png](attachment:image-2.png)
#
# Este proyecto busca proporcionar una visión integral del impacto económico de las colisiones severas y fatales, con el objetivo de informar la toma de decisiones y promover la seguridad vial en diversas comunidades y regiones geográficas.
#
# ### 1.4 Nodos y variables que se decidieron simular y porqué
#
# 1. **Colisiones  fatales por tipo de transporte**: Este nodo implicaría modelar la ocurrencia de colisiones  fatales para cada uno de los seis tipos de transporte (carro/pickup, camión, autobús, motocicleta, peatón y ciclista). Cada tipo de transporte podría tener su propio modelo de simulación para estimar la cantidad de colisiones y su impacto mortal.
#
# 2. **Colisiones fatales por region**: Este nodo implicaría modelar la ocurrencia de colisiones  fatales para cada uno de las regiones de california y asi podría tener su propio modelo de simulación para estimar la cantidad de colisiones y su impacto mortal.
#
# 3. **Población total (totalpop)**: La densidad de población en una determinada área podría influir en la gravedad y la frecuencia de las colisiones de tráfico Tasa de colisiones por cada 100,000 personas (poprate): Esta variable ya representa la tasa de colisiones ajustada por la población, lo que podría ser un predictor útil del número de muertos.
#
#
# 4. **Variación temporal de las tasas de colisión**: Este nodo implicaría modelar la variación temporal de las tasas de colisión a lo largo de los años disponibles (2002-2010). Esto podría ayudar a identificar tendencias a lo largo del tiempo y prever posibles cambios en el futuro.
#
# Estos nodos representan diferentes aspectos de la ocurrencia de colisiones severas y fatales, así como de las tasas de colisión en diferentes contextos geográficos y temporales. Modelar estos nodos en un proyecto de simulación financiera permitiría explorar el impacto económico de las colisiones y desarrollar estrategias de inversión y políticas de seguridad vial más efectivas.
#
# ### 1.5 Definición de hipótesis y supuestos.
#
# Definición de hipótesis y supuestos:
#
# **Hipótesis:**
# 1. **Hipótesis 1:** La tasa de colisiones severas y fatales se ve influenciada por factores como la densidad de población, el volumen de tráfico y las características de la infraestructura vial.
# 2. **Hipótesis 2:** Existe una relación directa entre el número de colisiones y el índice de desarrollo económico de una región.
# 3. **Hipótesis 3:** El comportamiento del tráfico y la frecuencia de colisiones siguen patrones estacionales y diarios predecibles.
# 4. **Hipótesis 4:** Las políticas de seguridad vial implementadas por las autoridades tienen un impacto significativo en la reducción de la tasa de colisiones severas y fatales.
# 5. **Hipótesis 5:** La edad, el sexo y la experiencia del conductor son variables que influyen en la probabilidad de estar involucrado en una colisión.
#
# **Supuestos:**
# 1. **Supuesto 1:** Los datos históricos de colisiones y variables demográficas son precisos y representativos de la realidad.
# 2. **Supuesto 2:** La infraestructura vial y las condiciones de tráfico permanecen constantes a lo largo del período de estudio.
# 3. **Supuesto 3:** La población y el comportamiento del tráfico en el futuro seguirán patrones similares a los observados en el pasado.
# 4. **Supuesto 4:** La metodología utilizada para la recolección y análisis de datos es válida y confiable.
# 5. **Supuesto 5:** Las políticas y regulaciones de seguridad vial se mantienen estables durante el período de estudio y no se producen cambios significativos en la legislación.
#
# ### 1.6 Obtención de bases de datos
#
# Los datos para este proyecto se obtuvieron de fuentes públicas y privadas, principalmente de data.gov y otras fuentes gubernamentales relacionadas con la seguridad vial y el transporte.
#
# 1. **Data.gov:** Se accedió a diversas bases de datos disponibles en data.gov, incluyendo el Statewide Integrated Traffic Records System (SWITRS) y el National Highway Traffic Safety Administration (NHTSA), que proporcionan información detallada sobre colisiones de tráfico, lesiones y fatalidades en carreteras.
#
# 2. **Instituciones gubernamentales:** Se consultaron datos de instituciones gubernamentales como la California Highway Patrol (CHP) y el Departamento de Transporte de California (Caltrans), que ofrecen datos actualizados sobre la infraestructura vial, el volumen de tráfico y las políticas de seguridad vial implementadas.
#
# 3. **Fuentes demográficas:** Se utilizaron datos demográficos provenientes del Departamento de Finanzas de California (DOF) y del U.S. Census Bureau, que proporcionan estimaciones de población y características socioeconómicas de las áreas geográficas relevantes.
#
# 4. **Encuestas y estudios:** Se analizaron encuestas como el National Household Travel Survey (NHTS) y estudios de investigación sobre seguridad vial y comportamiento del tráfico para complementar los datos disponibles y obtener una comprensión más completa de los factores que influyen en las colisiones y lesiones en carreteras.
#
# 5. **Bases de datos adicionales:** Se exploraron otras fuentes de datos, como informes de investigación académica, informes de agencias de seguridad vial y bases de datos de investigación en el ámbito de la ingeniería de tráfico y la seguridad vial.
#
# ---

# %% [markdown]
# iniciar con un histograma para cada  nodo con su distribucion de probabilidad de acuerdo a lo pedido ,
# validar

# %% [markdown]
# ### Nodo 1: Colisiones severas y fatales por tipo de transporte

# %%
# Importación de datos y librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
from collections import Counter
import warnings
warnings.filterwarnings("ignore")
import statsmodels.api as sm
from sklearn.neighbors import KernelDensity
from scipy.stats import gaussian_kde

# %%
# Lectura de datos desde el archivo 'road_traffic.xlsx'
data_raw = pd.read_excel("road_traffic.xlsx")
dt = pd.DataFrame(data_raw)

# %%
# Limpieza de datos para obtener el nodo 1 
# Filtrar las colisiones fatales
fatal_collisions = dt[dt['severity'] == 'Killed']
severa_collisions = dt[dt['severity'] == "Severe Injury"]

# Agrupar los datos por tipo de transporte y contar la cantidad de colisiones fatales
fatal_collisions_by_transport = fatal_collisions.groupby('mode').size()
severa_collisions_by_transport = severa_collisions.groupby('mode').size()

# Imprimir los resultados
print("Colisiones fatales por tipo de transporte:")
print(fatal_collisions_by_transport)

# Imprimir los resultados
print("Colisiones severas por tipo de transporte:")
print(severa_collisions_by_transport)
# Out:
# Colisiones fatales por tipo de transporte:
# mode
# All modes     44321
# Bicyclist      4456
# Bus             345
# Car/Pickup    31919
# Motorcycle    10304
# Pedestrian    16061
# Truck          1767
# Vehicles      35907
# dtype: int64
# Colisiones severas por tipo de transporte:
# mode
# All modes     82164
# Bicyclist     18412
# Bus             995
# Car/Pickup    64268
# Motorcycle    30014
# Pedestrian    30628
# Truck          4557
# Vehicles      71447
# dtype: int64

# %%
# Crear histograma de probabilidad de colisiones fatales por tipo de transporte
plt.figure(figsize=(10, 6))
sns.histplot(fatal_collisions_by_transport, kde=True, stat='probability', bins=10)
plt.title('Histograma de Probabilidad de Colisiones Fatales por Tipo de Transporte')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Probabilidad')
plt.grid(True)
plt.show()

# %%
# Definir datos de colisiones fatales por tipo de transporte
fatal_collisions_data = fatal_collisions_by_transport.values

# Definir límites del dominio
Domain = (min(fatal_collisions_data) - 1, max(fatal_collisions_data) + 1)

# Función de densidad de probabilidad para el método de aceptación-rechazo (opcional)
def f(x):
    # Aquí puedes definir tu propia función de densidad de probabilidad si es necesario
    return kde.evaluate(x)

# Función de aceptación-rechazo (aceptar si U < f(x) / M*g(x))
def acep_rechazo(N, Domain, f, M, g):
    samples = []
    count = 0
    while count < N:
        x = np.random.uniform(low=Domain[0], high=Domain[1])
        u = np.random.uniform(low=0, high=1)
        if u < f(x) / (M * g(x)):
            samples.append(x)
            count += 1
    return samples

# Definir grid para KDE
x_grid = np.linspace(min(fatal_collisions_data) - 1, max(fatal_collisions_data) + 1, 1000)

# Calcular KDE
kde = gaussian_kde(dataset=fatal_collisions_data, bw_method=0.139)
pdf = kde.evaluate(x_grid)

# Número de datos aleatorios a generar
N = 10000

# Generar datos aleatorios utilizando aceptación-rechazo
x_random = acep_rechazo(N, Domain, kde.evaluate, max(pdf), kde.evaluate)

# Graficar KDE y datos generados con aceptación-rechazo
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x_grid, pdf, color='orange', alpha=0.7, lw=3, label='KDE')
ax.hist(x_random, bins=60, density=True, alpha=0.5, label='Generados con Acep_Rechazo')
ax.set_xlim(min(fatal_collisions_data) - 1, max(fatal_collisions_data) + 1)

plt.title('Kernel Density e Histograma AyR')
plt.legend()
plt.show()

# %%
fatal_collisions_data = fatal_collisions_by_transport.values

# Calcular la densidad kernel
kde = gaussian_kde(fatal_collisions_data)

# Crear un rango de valores para evaluar la densidad kernel
x = np.linspace(min(fatal_collisions_data), max(fatal_collisions_data), 1000)

# Evaluar la densidad kernel en el rango de valores
kde_values = kde(x)

# Graficar la densidad kernel
plt.figure(figsize=(10, 6))
plt.plot(x, kde_values, label='Densidad Kernel Estimada', color='blue')
plt.fill_between(x, kde_values, alpha=0.2, color='blue')  # Rellenar el área bajo la curva
plt.title('Estimación de Densidad Kernel de Colisiones Fatales por Tipo de Transporte')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definir datos de colisiones fatales por tipo de transporte
fatal_collisions_data = fatal_collisions_by_transport.values

# Lista de distribuciones continuas para ajustar
rv_continuas = ['norm', 'lognorm', 'expon', 'gamma', 'weibull_min', 'skewnorm', 'loggamma', 'pearson3', 'beta', 'johnsonsb']

# Crear DataFrame para almacenar errores
error = pd.DataFrame(columns=['distribucion', 'error'])

# Inicializar gráfico
fig, ax = plt.subplots(figsize=(8, 4))

# Crear histograma de los datos
y, x, _ = ax.hist(fatal_collisions_data, bins=60, density=True, color='skyblue', alpha=0.7)

# Graficar el histograma de colisiones fatales por tipo de transporte
plt.title('Ajuste de Distribuciones a Colisiones Fatales por Tipo de Transporte')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Densidad de Probabilidad')
x = x[1:]

# Iterar sobre las distribuciones y ajustarlas a los datos
i = 0
for d_i in rv_continuas:
    try:
        params = getattr(st, d_i).fit(fatal_collisions_data)
        data_hat = getattr(st, d_i).pdf(x, *params)
        ax.plot(x, data_hat, label=d_i)
        error.loc[i, :] = [d_i, np.mean((y - data_hat)**2)]
        i += 1
    except ValueError:
        pass

# Mostrar leyenda y ajustar DataFrame de errores
plt.legend()
error.set_index('distribucion', inplace=True)
error.sort_values('error', inplace=True)

# %%
error.head(1)
# Out:
#              error
# distribucion
# gamma          0.0

# %%
# Definir datos de colisiones fatales por tipo de transporte
fatal_collisions_data = fatal_collisions_by_transport.values

# Ajustar la distribución Beta a los datos
params_beta = st.beta.fit(fatal_collisions_data)

# Generar datos basados en la distribución Beta ajustada
datos_beta = st.beta.rvs(*params_beta, size=len(fatal_collisions_data))

# Calcular la densidad kernel
kde = gaussian_kde(fatal_collisions_data)

# Crear un rango de valores para evaluar la densidad kernel
x = np.linspace(min(fatal_collisions_data), max(fatal_collisions_data), 1000)

# Evaluar la densidad kernel en el rango de valores
kde_values = kde(x)

# Crear el histograma con la distribución Beta y la densidad kernel
plt.figure(figsize=(10, 6))

# Histograma de los datos generados con la distribución Beta
plt.hist(datos_beta, bins=60, density=True, alpha=0.5, color='skyblue', label='Datos Generados con Beta')

# Densidad kernel estimada
plt.plot(x, kde_values, label='Densidad Kernel Estimada', color='orange')

plt.title('Histograma y Densidad Kernel con Distribución Beta')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.legend()
plt.show()

# %%
from statsmodels.graphics.gofplots import qqplot

# Realizar el gráfico Q-Q con la distribución Beta ajustada
qqplot(datos_beta, line='s')  # 's' para línea diagonal
plt.title('Gráfico Q-Q con Distribución Beta Ajustada')
plt.show()

# %%
# Parámetros de la distribución Beta ajustada
params_beta = st.beta.fit(fatal_collisions_data)

# Número de simulaciones de Monte Carlo
n_simulations = 1000

# Almacenar las varianzas calculadas en cada simulación
variances = []

# Generar muestras aleatorias y calcular la varianza en cada simulación
for _ in range(n_simulations):
    sampled_data = st.beta.rvs(*params_beta, size=len(fatal_collisions_data))
    variances.append(np.var(sampled_data))

# Calcular la media de las varianzas obtenidas en las simulaciones
monte_carlo_variance = np.mean(variances)

print("Varianza mediante Monte Carlo:", monte_carlo_variance)
# Out:
# Varianza mediante Monte Carlo: 275322465.3899965

# %%
def importance_sampling_monte_carlo(f, p, num_samples):
    # Generar muestras aleatorias de la distribución de importancia p(x)
    samples = p.rvs(size=num_samples)
    
    # Calcular el valor de h(x) para cada muestra
    h_values = f(samples) / p.pdf(samples)
    
    # Estimar la media utilizando el promedio de h(x)
    estimated_mean = np.mean(h_values)
    
    return estimated_mean

# Definir la función de densidad de probabilidad f(x) que se quiere estimar (por ejemplo, una distribución gamma)
f = st.gamma(a=2)  # Por ejemplo, una distribución gamma con parámetro de forma a=2

# Definir la distribución de importancia p(x) (por ejemplo, una distribución normal)
p = st.norm(loc=2, scale=1)  # Por ejemplo, una distribución normal con media 2 y desviación estándar 1

# Número de muestras para generar
num_samples = 10000

# Estimar la media utilizando el método de Monte Carlo con muestreo por importancia
estimated_mean = importance_sampling_monte_carlo(f.pdf, p, num_samples)

print("Media estimada:", estimated_mean)
# Out:
# Media estimada: 0.9854512114903009

# %%
# Definir el nivel de significancia alpha
alpha = 0.05  # Por ejemplo, un nivel de significancia del 5%

# Definir el valor crítico basado en el nivel de significancia y la distribución de importancia
valor_critico = p.ppf(1 - alpha)  # Percentil correspondiente al nivel de significancia

# Comparar el valor crítico con la media estimada
if estimated_mean > valor_critico:
    print("Se rechaza la hipótesis nula (H0)")
    print("La media estimada es significativamente mayor que el valor crítico.")
else:
    print("No se rechaza la hipótesis nula (H0)")
# Out:
# No se rechaza la hipótesis nula (H0)

# %% [markdown]
# #### Distribución de probabilidad

# %%
# Datos proporcionados
fatal_collisions_counts = {'All modes': 44321, 'Bicyclist': 4456, 'Bus': 345, 'Car/Pickup': 31919,
                           'Motorcycle': 10304, 'Pedestrian': 16061, 'Truck': 1767, 'Vehicles': 35907}
severa_collisions_counts = {'All modes': 82164, 'Bicyclist': 18412, 'Bus': 995, 'Car/Pickup': 64268,
                            'Motorcycle': 30014, 'Pedestrian': 30628, 'Truck': 4557, 'Vehicles': 71447}

# Calcular las probabilidades de colisiones fatales y severas para cada tipo de transporte
total_fatal_collisions = sum(fatal_collisions_counts.values())
total_severa_collisions = sum(severa_collisions_counts.values())

fatal_probabilities = {mode: count / total_fatal_collisions for mode, count in fatal_collisions_counts.items()}
severa_probabilities = {mode: count / total_severa_collisions for mode, count in severa_collisions_counts.items()}

# Imprimir las probabilidades
print("Probabilidades de colisiones fatales por tipo de transporte:")
print(fatal_probabilities)
print("\nProbabilidades de colisiones severas por tipo de transporte:")
print(severa_probabilities)
# Out:
# Probabilidades de colisiones fatales por tipo de transporte:
# {'All modes': 0.3054935208161015, 'Bicyclist': 0.030714088778604907, 'Bus': 0.002377998345740281, 'Car/Pickup': 0.22000964984835952, 'Motorcycle': 0.07102288392610974, 'Pedestrian': 0.11070443893024538, 'Truck': 0.01217948717948718, 'Vehicles': 0.24749793217535154}
#
# Probabilidades de colisiones severas por tipo de transporte:
# {'All modes': 0.271629998181728, 'Bicyclist': 0.06086913400664496, 'Bus': 0.0032894193100484323, 'Car/Pickup': 0.2124667338876308, 'Motorcycle': 0.09922475494652627, 'Pedestrian': 0.10125460766649585, 'Truck': 0.015065209845116287, 'Vehicles': 0.23620014215580937}

# %%
# Crear un DataFrame con las probabilidades
df_fatal = pd.DataFrame.from_dict(fatal_probabilities, orient='index', columns=['Probabilidad Fatal'])
df_severa = pd.DataFrame.from_dict(severa_probabilities, orient='index', columns=['Probabilidad Severa'])

# Imprimir los DataFrames
print("\nDataFrame de probabilidades de colisiones fatales:")
print(df_fatal)
print("\nDataFrame de probabilidades de colisiones severas:")
print(df_severa)
# Out:
# DataFrame de probabilidades de colisiones fatales:
#             Probabilidad Fatal
# All modes             0.305494
# Bicyclist             0.030714
# Bus                   0.002378
# Car/Pickup            0.220010
# Motorcycle            0.071023
# Pedestrian            0.110704
# Truck                 0.012179
# Vehicles              0.247498
#
# DataFrame de probabilidades de colisiones severas:
#             Probabilidad Severa
# All modes              0.271630
# Bicyclist              0.060869
# Bus                    0.003289
# Car/Pickup             0.212467
# Motorcycle             0.099225
# Pedestrian             0.101255
# Truck                  0.015065
# Vehicles               0.236200

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 10))

# Gráfico de probabilidades de colisiones fatales
df_fatal = pd.DataFrame.from_dict(fatal_probabilities, orient='index', columns=['Probabilidad Fatal'])
df_fatal.plot(kind='bar', ax=axes[0], color='skyblue')
axes[0].set_title('Probabilidades de colisiones fatales por tipo de transporte')
axes[0].set_ylabel('Probabilidad')
axes[0].grid(True)

# Gráfico de probabilidades de colisiones severas
df_severa = pd.DataFrame.from_dict(severa_probabilities, orient='index', columns=['Probabilidad Severa'])
df_severa.plot(kind='bar', ax=axes[1], color='lightgreen')
axes[1].set_title('Probabilidades de colisiones severas por tipo de transporte')
axes[1].set_ylabel('Probabilidad')
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### NODO 2:

# %%
# Limpieza de datos para obtener el nodo 2 
# Filtrar las colisiones fatales
fatal_collisions = dt[dt['severity'] == 'Killed']


# Agrupar los datos por tipo de transporte y contar la cantidad de colisiones fatales
fatal_collisions_by_region = fatal_collisions.groupby('region_name').size()


# Imprimir los resultados
print("Colisiones fatales por tipo de region:")
print(fatal_collisions_by_region)


# Crear histograma de probabilidad de colisiones fatales por tipo de region
plt.figure(figsize=(10, 6))
sns.histplot(fatal_collisions_by_transport, kde=True, stat='probability', bins=10)
plt.title('Histograma de Probabilidad de region por killed')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Probabilidad')
plt.grid(True)
plt.show()
# Out:
# Colisiones fatales por tipo de region:
# region_name
# Bay Area                       5510
# Butte                           589
# Central/Southeast Sierra       1239
# Monterey Bay                   1199
# North Coast                    1238
# Northeast Sierra                794
# Northern Sacramento Valley      456
# Sacramento Area                2780
# San Diego                      1905
# San Joaquin Valley             4837
# San Luis Obispo                 548
# Santa Barbara                   611
# Shasta                          417
# Southern California           13192
# dtype: int64

# %%
# Limpieza de datos para obtener el nodo 1 
# Filtrar las colisiones fatales
fatal_collisions = dt[dt['severity'] == 'Killed']

# Agrupar los datos por tipo de transporte y contar la cantidad de colisiones fatales
fatal_collisions_by_region = fatal_collisions.groupby('region_name').size()

# Imprimir los resultados
print("Colisiones fatales por tipo de region:")
print(fatal_collisions_by_region)

# Crear histograma de probabilidad de colisiones fatales por tipo de region
plt.figure(figsize=(10, 6))
sns.histplot(fatal_collisions_by_region, kde=True, stat='probability', bins=10)
plt.title('Histograma de Probabilidad de region por killed')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Probabilidad')
plt.grid(True)
plt.show()

# Definir datos de colisiones fatales por tipo de región
fatal_collisions_data = fatal_collisions_by_region.values

# Calcular KDE
kde = gaussian_kde(dataset=fatal_collisions_data, bw_method=0.139)

# Definir límites del dominio
Domain = (min(fatal_collisions_data) - 1, max(fatal_collisions_data) + 1)

# Función de densidad de probabilidad para el método de aceptación-rechazo
def f(x):
    return kde.evaluate(x)

# Función de aceptación-rechazo
def acep_rechazo(N, Domain, f, M, g):
    samples = []
    count = 0
    while count < N:
        x = np.random.uniform(low=Domain[0], high=Domain[1])
        u = np.random.uniform(low=0, high=1)
        if u < f(x) / (M * g(x)):
            samples.append(x)
            count += 1
    return samples

# Definir grid para KDE
x_grid = np.linspace(min(fatal_collisions_data) - 1, max(fatal_collisions_data) + 1, 1000)
pdf = kde.evaluate(x_grid)

# Número de datos aleatorios a generar
N = 10000

# Generar datos aleatorios utilizando aceptación-rechazo
x_random = acep_rechazo(N, Domain, kde.evaluate, max(pdf), kde.evaluate)

# Graficar KDE y datos generados con aceptación-rechazo
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x_grid, pdf, color='orange', alpha=0.7, lw=3, label='KDE')
ax.hist(x_random, bins=60, density=True, alpha=0.5, label='Generados con Acep_Rechazo')
ax.set_xlim(min(fatal_collisions_data) - 1, max(fatal_collisions_data) + 1)

plt.title('Kernel Density e Histograma AyR')
plt.legend()
plt.show()

# Calcular la densidad kernel
kde = gaussian_kde(fatal_collisions_data)

# Crear un rango de valores para evaluar la densidad kernel
x = np.linspace(min(fatal_collisions_data), max(fatal_collisions_data), 1000)

# Evaluar la densidad kernel en el rango de valores
kde_values = kde(x)

# Graficar la densidad kernel
plt.figure(figsize=(10, 6))
plt.plot(x, kde_values, label='Densidad Kernel Estimada', color='blue')
plt.fill_between(x, kde_values, alpha=0.2, color='blue')  
plt.title('Estimación de Densidad Kernel de Colisiones Fatales por Tipo de región')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.legend()
plt.show()

# Ajuste de distribuciones continuas
rv_continuas = ['norm', 'lognorm', 'expon', 'gamma', 'weibull_min', 'skewnorm', 'loggamma', 'pearson3', 'beta', 'johnsonsb']

# Crear DataFrame para almacenar errores
error = pd.DataFrame(columns=['distribucion', 'error'])

# Inicializar gráfico
fig, ax = plt.subplots(figsize=(8, 4))

# Crear histograma de los datos
y, x, _ = ax.hist(fatal_collisions_data, bins=100, density=True, color='skyblue', alpha=0.7)

# Graficar el histograma de colisiones fatales por tipo de región
plt.title('Ajuste de Distribuciones a Colisiones Fatales por Tipo de región')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Densidad de Probabilidad')
x = x[1:]

# Iterar sobre las distribuciones y ajustarlas a los datos
i = 0
for d_i in rv_continuas:
    try:
        params = getattr(st, d_i).fit(fatal_collisions_data)
        data_hat = getattr(st, d_i).pdf(x, *params)
        ax.plot(x, data_hat, label=d_i)
        error.loc[i, :] = [d_i, np.mean((y - data_hat)**2)]
        i += 1
    except ValueError:
        pass

# Mostrar leyenda y ajustar DataFrame de errores
plt.legend()
error.set_index('distribucion', inplace=True)
error.sort_values('error', inplace=True)

# Imprimir los primeros 10 errores
print(error.head(10))

# Ajuste específico con distribución Beta
params_beta = st.beta.fit(fatal_collisions_data)
datos_beta = st.beta.rvs(*params_beta, size=len(fatal_collisions_data))

# Calcular la densidad kernel
kde = gaussian_kde(fatal_collisions_data)

# Crear un rango de valores para evaluar la densidad kernel
x = np.linspace(min(fatal_collisions_data), max(fatal_collisions_data), 1000)

# Evaluar la densidad kernel en el rango de valores
kde_values = kde(x)

# Crear el histograma con la distribución Beta y la densidad kernel
plt.figure(figsize=(10, 6))

# Histograma de los datos generados con la distribución Beta
plt.hist(datos_beta, bins=60, density=True, alpha=0.5, color='skyblue', label='Datos Generados con Beta')

# Densidad kernel estimada
plt.plot(x, kde_values, label='Densidad Kernel Estimada', color='orange')

plt.title('Histograma y Densidad Kernel con Distribución Beta')
plt.xlabel('Colisiones Fatales')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Colisiones fatales por tipo de region:
# region_name
# Bay Area                       5510
# Butte                           589
# Central/Southeast Sierra       1239
# Monterey Bay                   1199
# North Coast                    1238
# Northeast Sierra                794
# Northern Sacramento Valley      456
# Sacramento Area                2780
# San Diego                      1905
# San Joaquin Valley             4837
# San Luis Obispo                 548
# Santa Barbara                   611
# Shasta                          417
# Southern California           13192
# dtype: int64
#                 error
# distribucion
# lognorm           0.0
# gamma             0.0
# weibull_min       0.0
# pearson3          0.0
# expon             0.0
# beta              0.0
# skewnorm          0.0
# norm              0.0
# loggamma          0.0
# johnsonsb     0.00001

# %%
def red_var_montecarlo(data, N):
    # Calcula la media muestral
    sample_mean = np.mean(data)
    
    # Genera N muestras aleatorias
    samples = np.random.choice(data, size=N, replace=True)
    
    # Calcula la media muestral de las muestras generadas
    sample_mean_mc = np.mean(samples)
    
    # Calcula el error relativo
    relative_error = np.abs((sample_mean - sample_mean_mc) / sample_mean) * 100
    
    return sample_mean, sample_mean_mc, relative_error

# Llamada a la función para calcular la reducción de varianza
media_muestral, media_muestral_mc, error_relativo = red_var_montecarlo(fatal_collisions_by_region.values, 10000)

print("La media muestral estimada es:", media_muestral)
print("La media muestral estimada con reducción de varianza es:", media_muestral_mc)
print("Error relativo:", error_relativo)
# Out:
# La media muestral estimada es: 2522.5
# La media muestral estimada con reducción de varianza es: 2487.906
# Error relativo: 1.3714172447968305

# %%
# Obtener los datos de colisiones fatales por tipo de región
fatal_collisions_data = fatal_collisions_by_region.values

# Generar muestras aleatorias de una distribución normal con la misma media y desviación estándar que los datos
normal_samples = np.random.normal(np.mean(fatal_collisions_data), np.std(fatal_collisions_data), len(fatal_collisions_data))

# Calcular los cuantiles de los datos reales y de las muestras normales
quantiles_data = np.percentile(fatal_collisions_data, np.linspace(0, 100, 100))
quantiles_normal = np.percentile(normal_samples, np.linspace(0, 100, 100))

# Graficar el Q-Q plot
plt.figure(figsize=(8, 8))
plt.scatter(quantiles_normal, quantiles_data)
plt.plot([np.min(quantiles_normal), np.max(quantiles_normal)], [np.min(quantiles_normal), np.max(quantiles_normal)], color='red', linestyle='--')
plt.title('Q-Q Plot de Colisiones Fatales por Tipo de región')
plt.xlabel('Cuantiles de Distribución Normal')
plt.ylabel('Cuantiles de Datos de Colisiones Fatales')
plt.grid(True)
plt.show()

# %%
from scipy.stats import shapiro

# Realizar la prueba de Shapiro-Wilk
stat, p_value = shapiro(fatal_collisions_data)

# Imprimir el resultado de la prueba
print("Estadístico de prueba:", stat)
print("Valor p:", p_value)

# Comprobar si se rechaza la hipótesis nula (H0)
alpha = 0.05
if p_value > alpha:
    print("No se puede rechazar la hipótesis nula (H0) de normalidad")
else:
    print("Se rechaza la hipótesis nula (H0) de normalidad")
# Out:
# Estadístico de prueba: 0.642071545124054
# Valor p: 9.871184010989964e-05
# Se rechaza la hipótesis nula (H0) de normalidad

# %% [markdown]
# #### Distribución de probabilidad

# %%
fatal_collisions_by_region = {
    'Bay Area': 5510, 'Butte': 589, 'Central/Southeast Sierra': 1239, 'Monterey Bay': 1199,
    'North Coast': 1238, 'Northeast Sierra': 794, 'Northern Sacramento Valley': 456, 'Sacramento Area': 2780,
    'San Diego': 1905, 'San Joaquin Valley': 4837, 'San Luis Obispo': 548, 'Santa Barbara': 611,
    'Shasta': 417, 'Southern California': 13192
}

# Calcular la probabilidad de colisiones fatales por tipo de región
total_fatal_collisions = sum(fatal_collisions_by_region.values())
fatal_probabilities_by_region = {region: count / total_fatal_collisions for region, count in fatal_collisions_by_region.items()}

# Crear DataFrame para facilitar la visualización
df_fatal_probabilities = pd.DataFrame.from_dict(fatal_probabilities_by_region, orient='index', columns=['Probabilidad'])

# Ordenar el DataFrame por probabilidad descendente
df_fatal_probabilities = df_fatal_probabilities.sort_values(by='Probabilidad', ascending=False)

# Gráfico de barras de la distribución de probabilidad de colisiones fatales por tipo de región
plt.figure(figsize=(10, 6))
plt.bar(df_fatal_probabilities.index, df_fatal_probabilities['Probabilidad'], color='hotpink')
plt.title('Distribución de probabilidad de colisiones fatales por región')
plt.xlabel('Región')
plt.ylabel('Probabilidad')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### NODO 3: Comparación entre diferentes áreas geográficas

# %%
# Lectura de datos desde el archivo 'road_traffic.xlsx'
data_raw = pd.read_excel("road_traffic.xlsx")
dt = pd.DataFrame(data_raw)

# Eliminar filas con valores nulos en las columnas relevantes
dt_cleaned = dt.dropna(subset=['avmtrate', 'totalpop'])

# Calcular la tasa de mortalidad por cada 100,000 habitantes
dt_cleaned['mortality_rate_per_100k'] = (dt_cleaned['avmtrate'] / dt_cleaned['totalpop']) * 100000

# Graficar la relación entre la población total y la tasa de mortalidad
plt.figure(figsize=(10, 6))
plt.scatter(dt_cleaned['totalpop'], dt_cleaned['mortality_rate_per_100k'], alpha=0.5)
plt.title('Relación entre Población Total y Tasa de Mortalidad')
plt.xlabel('Población Total')
plt.ylabel('Tasa de Mortalidad por 100,000 habitantes')
plt.grid(True)
plt.show()

# %% [markdown]
# ### NODO 4: Variación temporal de las tasas de colisión

# %%
# Leer los datos desde el archivo 'road_traffic.xlsx'
data_raw = pd.read_excel("road_traffic.xlsx")
dt = pd.DataFrame(data_raw)

# Eliminar filas con valores vacíos
dt.dropna(inplace=True)

# Convertir la columna 'reportyear' a formato de fecha
dt['reportyear'] = pd.to_datetime(dt['reportyear'], format='%Y')

# Agrupar los datos por año y calcular la tasa de colisión promedio de cada año
collision_rates_by_year = dt.groupby(dt['reportyear'].dt.year)['avmtrate'].mean()

# Graficar la variación temporal de las tasas de colisión a lo largo de los años
plt.figure(figsize=(10, 6))
plt.plot(collision_rates_by_year.index, collision_rates_by_year.values, marker='o', linestyle='-')
plt.title('Variación Temporal de las Tasas de Colisión (2002-2010)')
plt.xlabel('Año')
plt.ylabel('Tasa de Colisión')
plt.grid(True)
plt.xticks(collision_rates_by_year.index)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/p6/h00j87g13kg92yz0p85rtz5c0000gn/T/ipykernel_42152/185059855.py in <module>
#       7
# ...

# %% [markdown]
# NODO 3 y 4
# Población total (totalpop): La densidad de población en una determinada área podría influir en la gravedad y la frecuencia de las colisiones de tráfico.
# Tasa de colisiones por cada 100,000 personas (poprate): Esta variable ya representa la tasa de colisiones ajustada por la población, lo que podría ser un predictor útil del número de muertos.

# %%
# Lectura de datos desde el archivo 'road_traffic.xlsx'
data_raw = pd.read_excel("road_traffic.xlsx")
dt = pd.DataFrame(data_raw)

population_and_poprate = dt[['totalpop', 'poprate']]

# Mostrar información de las primeras filas para verificar
print(population_and_poprate.head())

# %%
# Seleccionar las columnas de interés
population_and_poprate = dt[['totalpop', 'poprate']]

# Eliminar filas con valores faltantes en las columnas seleccionadas
population_and_poprate = population_and_poprate.dropna()

# Definir el tamaño del gráfico
plt.figure(figsize=(12, 6))

# Histograma de la población total
plt.subplot(1, 2, 1)
plt.hist(population_and_poprate['totalpop'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribución de Población Total')
plt.xlabel('Población Total')
plt.ylabel('Frecuencia')

# Histograma de la tasa de colisiones por cada 100,000 personas
plt.subplot(1, 2, 2)
plt.hist(population_and_poprate['poprate'], bins=20, color='orange', edgecolor='black')
plt.title('Distribución de Tasa de Colisiones (por 100,000 personas)')
plt.xlabel('Tasa de Colisiones')
plt.ylabel('Frecuencia')

# Ajustar diseño y mostrar el gráfico
plt.tight_layout()
plt.show()
